# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 5</span> - <span style="color:red"> Only for master students</span>

# %% [markdown]
# In quantum physics a **wave function**, $\Psi$, is a mathematical description of the state of a quantum system. The wave function is a complex-valued probability amplitude, and the probabilities for the possible results of measurements made on the system can be derived from it.
#
# For now on, let's consider the simple case of a non-relativistic single particle, without spin, in three spatial dimensions. The state of such a particle is completely described by its wave function, $\Psi(\vec{r},t)$, where $\vec{r}$ is position and $t$ is time.
#
# For one spinless particle, if the wave function is interpreted as a probability amplitude, the square modulus of the wave function, $|\Psi(\vec{r},t)|^2$, is interpreted as the probability density that the particle is at $\vec{r}$ at time $t$. Once we have a probability density, we can use Monte Carlo ...
#
# #### Hydrogen atom
# The wave functions of the eigenstates of an electron in a Hydrogen atom (this is the only atom for which the Schroedinger equation has been solved exactly) are expressed in terms of spherical harmonics and generalized Laguerre polynomials. It is convenient to use spherical coordinates, and the wave function can be separated into functions of each coordinate:
#
# $$
# \Psi_{n,l,m}(r,\theta,\phi)=
# \sqrt{\left(\frac{2}{na_0}\right)^3 \frac{(n-l-1)!}{2n[(n+l)!]}}
# e^{-r/na_0}\left(\frac{2r}{na_0}\right)^l L_{n-l-1}^{2l+1}\left(\frac{2r}{na_0}\right)
# Y_l^m(\theta,\phi)
# $$
#
# where $a_0=4\pi\epsilon_0\hbar^2/m_e e^2=0.0529$ nm is the Bohr radius, $L_{n-l-1}^{2l+1}$ are the generalized Laguerre polynomials of degree $n-l-1$, $n=1,2,...$ is the principal quantum number, $l=0,1, ..., n-1$ the azimuthal quantum number, $m=-l, -l+1, ..., l-1, l$ the magnetic quantum number.
#
# For example, the ground state wave function is:
# $$
# \Psi_{1,0,0}(r,\theta,\phi)=
# \frac{a_0^{-3/2}}{\sqrt{\pi}} e^{-r/a_0}
# $$
# whereas one of the three $2p$ excited state is:
# $$
# \Psi_{2,1,0}(r,\theta,\phi)=
# \frac{a_0^{-5/2}}{8}\sqrt{\frac{2}{\pi}} r e^{-r/2a_0} \cos(\theta)
# $$
# <span style="color:blue">Expectation values for the radius turns out to be exactly:
# $$
# \left\langle r \right\rangle_{\Psi_{1,0,0}} = \frac{3}{2}a_0
# \quad
# \left\langle r \right\rangle_{\Psi_{2,1,0}} = 5 a_0
# $$
# </span>
#
#
# ### Exercise 05.1
#
#
# Use the Metropolis algorithm to sample $|\Psi_{1,0,0}(x,y,z)|^2$ and $|\Psi_{2,1,0}(x,y,z)|^2$ **in Cartesian coordinates** using, initially, an uniform transition probability $T(\vec{x}|\vec{y})$. Use the sampled positions to estimate $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$. As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# <span style="color:red">Show a picture of your estimations of $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$</span> and their uncertainties with a large number of *throws* $M$ (e.g. $M\ge 10^6$) as a function of the number of blocks, $N$</font>.
#
# - Use Bohr radius units, $a_0$ for distances
# - Choose the step of the uniform transition probability $T(\vec{x}|\vec{y})$ in order to obtain 50% of acceptance in both cases
# - Choose a reasonable starting point in the 3D space and equilibrate your sampling before to start measuring the radius. What do you observe when you start very far from the origin?
# - How large should be the number of Monte Carlo Metropolis steps in each block?
# - <span style="color:red">If you use a multivariate normal transition probability $T(\vec{x}|\vec{y})$, i.e. a Gaussian for each coordinate, your results for $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$ are equivalent?</span>

# %% [markdown]
# You can use a Python code similar to the following one to observe how the sampled points distribute into the 3D space:

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

M=1000
X=np.random.normal(0.0,1.0,M)
Y=np.random.normal(0.0,1.0,M)
Z=np.random.normal(0.0,1.0,M)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(10, 30)

plt.show()

# %% [markdown]
# In questo caso ho fatto partire la simulazione dal punto iniziale $(0, 0, 0)$ per quanto riguarda il campionamento della $P_{(1,0,0)}$.
#
# Questo punto iniziale è ragionevole perché è il **massimo** della **densità di probabilità** dello stato fondamentale dell'atomo di idrogeno. Partire da $(0,0,0)$ significa posizionare la particella fin dal primo passo nella regione a più alta densità di probabilità, minimizzando il tempo necessario all'algoritmo per trovare la zona di interesse.
#
# Nel grafico sottostate possiamo notare come il valore stimato di $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ vada a convergere al valore teorico all'aumentare del numero di blocchi $N$.
#
# Ho utilizzato $N = 200$ blocchi e $L = 500$ simulazioni per blocco.

# %%
data100 = np.loadtxt('100.dat')

x = data100[:, 0]
y = data100[:, 1]  
y_err = data100[:, 2]


plt.figure(figsize=(10, 6))
plt.errorbar(x, y, yerr=y_err, color='blue', ecolor='red', label='<r>', capsize=2, fmt='-o', markersize=2)
plt.axhline(1.5, color = 'green', label = 'valore vero')
plt.xlabel('Numero di blocchi ($N$)', fontsize=12)
plt.ylabel('Valore stimato', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Ho provato a utilizzare come punto iniziale $(100 \, a_0, 100 \, a_0, 100 \, a_0)$ e sorprendentemente l'algoritmo converge perfettamente al valore vero.
#
# Ho utilizzato $N = 200$ blocchi e $L = 500$ simulazioni per blocco.

# %%
data100 = np.loadtxt('100_very_far.dat')

x = data100[:, 0]
y = data100[:, 1]  
y_err = data100[:, 2]


plt.figure(figsize=(10, 6))
plt.errorbar(x, y, yerr=y_err, color='blue', ecolor='red', label='<r>', capsize=2, fmt='-o', markersize=2)
plt.axhline(1.5, color = 'green', label = 'valore vero')
plt.xlabel('Numero di blocchi ($N$)', fontsize=12)
plt.ylabel('Valore stimato', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Ho fatto un'altra prova utilizzando come punto iniziale $(50 \, a_0, 50 \, a_0, 100 \, a_0)$. L'algoritmo converge al valore vero un po' peggio rispetto a prima.
#
# Ho utilizzato $N = 200$ blocchi e $L = 500$ simulazioni per blocco.

# %%
data100 = np.loadtxt('100_far.dat')

x = data100[:, 0]
y = data100[:, 1]  
y_err = data100[:, 2]


plt.figure(figsize=(10, 6))
plt.errorbar(x, y, yerr=y_err, color='blue', ecolor='red', label='<r>', capsize=2, fmt='-o', markersize=2)
plt.axhline(1.5, color = 'green', label = 'valore vero')
plt.xlabel('Numero di blocchi ($N$)', fontsize=12)
plt.ylabel('Valore stimato', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Ho utilizzato $N = 200$ blocchi e $L = 500$ simulazioni per blocco.

# %%
data210 = np.loadtxt('210.dat')

x = data210[:, 0]
y = data210[:, 1]  
y_err = data210[:, 2]


plt.figure(figsize=(10, 6))
plt.errorbar(x, y, yerr=y_err, color='blue', ecolor='red', label='<r>', capsize=2, fmt='-o', markersize=2)
plt.axhline(5, color = 'green', label = 'valore vero')
plt.xlabel('Numero di blocchi ($N$)', fontsize=12)
plt.ylabel('Valore stimato', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# In questa simulazione sono partito dal punto iniziale $(100 \, a_0, 100 \, a_0, 100 \, a_0)$ e poichè con $N = 200$ blocchi e $L = 500$ simulazioni per blocco non riuscivo a ottenere una buona convergenza ho aumentato a $L = 5000$ simulazioni per blocco, ottenendo un'ottima convergenza.

# %%
data210 = np.loadtxt('210_far.dat')

x = data210[:, 0]
y = data210[:, 1]  
y_err = data210[:, 2]


plt.figure(figsize=(10, 6))
plt.errorbar(x, y, yerr=y_err, color='blue', ecolor='red', label='<r>', capsize=2, fmt='-o', markersize=2)
plt.axhline(5, color = 'green', label = 'valore vero')
plt.xlabel('Numero di blocchi ($N$)', fontsize=12)
plt.ylabel('Valore stimato', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# #### Proprietà di simmetria della transizione Gaussiana
#
# Nel caso in cui si scelga di proporre la mossa tramite una distribuzione normale multivariata , la probabilità di transizione assume la forma:
#
# $$T_{\text{gauss}}(\vec{x}|\vec{y}) = \frac{1}{(2\pi\sigma^2)^{3/2}} e^{-\frac{|\vec{x}-\vec{y}|^2}{2\sigma^2}}=\frac{1}{(2\pi\sigma^2)^{3/2}} e^{-\frac{|\vec{y}-\vec{x}|^2}{2\sigma^2}} = T_{\text{gauss}}(\vec{y}|\vec{x})$$
#
#
#
# $$\frac{T_{\text{gauss}}(\vec{y}|\vec{x})}{T_{\text{gauss}}(\vec{x}|\vec{y})} = 1$$
#
# Di conseguenza, la probabilità di accettazione finale $A(\vec{x}|\vec{y})$ diventa:
#
# $$A(\vec{x}|\vec{y}) = \min \left\{ 1, \frac{T_{\text{gauss}}(\vec{y}|\vec{x}) P(\vec{x})}{T_{\text{gauss}}(\vec{x}|\vec{y}) P(\vec{y})} \right\} = \min \left\{ 1, \frac{P(\vec{x})}{P(\vec{y})} \right\} = \text{al caso della probabilità uniforme}$$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

data_position100 = np.loadtxt('position_100.dat')

X=data_position100[:,0]
Y=data_position100[:,1]
Z=data_position100[:,2]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(10, 30)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

data_position210 = np.loadtxt('position_210.dat')

X=data_position210[:,0]
Y=data_position210[:,1]
Z=data_position210[:,2]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(10, 30)

plt.show()

# %% [markdown]
# <span style="color:red"> **Non richiesto** </span> Visualizzazione con l'asse z "stirato"

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt('position_210.dat')

X = data[:, 0]
Y = data[:, 1]
Z = data[:, 2]

fig = plt.figure(figsize=(12, 12)) 
ax = fig.add_subplot(projection='3d')
sc = ax.scatter(X, Y, Z, c=Z, marker='.', s=0.5)
ax.set_box_aspect([1, 1, 2]) 
limit = 15
ax.set_xlim(-limit, limit)
ax.set_ylim(-limit, limit)
ax.set_zlim(-limit, limit)
ax.set_xlabel('x ($a_0$)')
ax.set_ylabel('y ($a_0$)')
ax.set_zlabel('z ($a_0$)')
ax.set_title('Orbitale $2,1,0$')
ax.view_init(elev=15, azim=30)
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
plt.tight_layout()
plt.show()
